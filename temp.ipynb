# %%
import pandas as pd
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import OneHotEncoder

cat_cols = ['Industry', 'Location']
TruncatedSVD
data = pd.read_csv('/home/ubuntu/crawl/crawler-recommend-sys/data/sample.csv')
ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=True)
_ = ohe.fit(data[cat_cols]).fillna('')
# Out:
# Index(['reviewer_name', 'reviewer_role', 'reviewer_company', 'verified_status',
#        'Industry', 'Location', 'Client size', 'Review type', 'Services',
#        'Project size', 'Project length', 'Project description', 'background',
#        'reviewer_position_raw', 'linkedin Company Outsource',
#        'twitter Company Outsource', 'instagram Company Outsource',
#        'facebook Company Outsource'],
#       dtype='object')
