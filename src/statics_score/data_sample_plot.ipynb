# %%
import pandas as pd
data = pd.read_csv('/home/ubuntu/crawl/crawler-recommend-sys/data/sample_0_100.csv')
print(data.groupby('Industry')['Client size'].value_counts().to_string())
# Out:
# Industry                                Client size
# Advertising & marketing                 1-10 Employees            367
#                                         11-50 Employees           362
#                                         51-200 Employees          158
#                                         201-500 Employees          39
#                                         501-1,000 Employees        24
#                                         1,001-5,000 Employees      10
#                                         5,001-10,000 Employees      8
#                                         10,001+ Employees           7
# Agriculture                             1-10 Employees             20
#                                         11-50 Employees            19
#                                         51-200 Employees           14
#                                         501-1,000 Employees         9
#                                         1,001-5,000 Employees       8
# ...
